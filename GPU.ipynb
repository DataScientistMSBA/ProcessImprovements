# %% [markdown]
# <a href="https://colab.research.google.com/github/DataScientistMSBA/ProcessImprovements/blob/main/GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [Script source](https://www.geeksforgeeks.org/running-python-script-on-gpu/)

# %%
pip install numba & conda install cudatoolkit
# Out:
# /bin/bash: conda: command not found
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from numba import jit, cuda
import numpy as np
# to measure exec time
from timeit import default_timer as timer   
  
# normal function to run on cpu
def func(a):                                
    for i in range(10000000):
        a[i]+= 1      
  
# function optimized to run on gpu 
@jit(target ="cuda")                         
def func2(a):
    for i in range(10000000):
        a[i]+= 1
if __name__=="__main__":
    n = 10000000                            
    a = np.ones(n, dtype = np.float64)
    b = np.ones(n, dtype = np.float32)
      
    start = timer()
    func(a)
    print("without GPU:", timer()-start)    
      
    start = timer()
    func2(a)
    print("with GPU:", timer()-start)
# Out:
# /usr/local/lib/python3.7/dist-packages/numba/core/decorators.py:150: NumbaDeprecationWarning: The 'target' keyword argument is deprecated.
#   warnings.warn("The 'target' keyword argument is deprecated.", NumbaDeprecationWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-daf7b2c4f2cf> in <module>()
#      10
#      11 # function optimized to run on gpu
# ---> 12 @jit(target ="cuda")
#      13 def func2(a):
#      14     for i in range(10000000):
#
# /usr/local/lib/python3.7/dist-packages/numba/core/decorators.py in wrapper(func)
#     207         disp = dispatcher(py_func=func, locals=locals,
#     208                           targetoptions=targetoptions,
# --> 209                           **dispatcher_args)
#     210         if cache:
#     211             disp.enable_caching()
#
# TypeError: __init__() got an unexpected keyword argument 'py_func'
